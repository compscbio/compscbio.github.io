# %% [markdown]
# # Homework #2
#
# Due 11:59 pm EST, **Sunday Feb 20th, 2022**
# Email your solutions (both .ipnb and .html files) to:
# compscbio@gmail.com.
#
# ### Goals: force the student to gain practical experience with
# - annData
# - scanpy
# - cleaning scRNAseq data
# - how parameters impact analysis outcomes

# %% [markdown]
# Prepare this data for the students, then walk through types of analysis that I will ask of them.
#
# see Evernote "rescue negatives from R1 -- take III"

# %%
import pandas as pd
import seaborn as sns
import scanpy as sc
import scipy as sp
import numpy as np
import matplotlib.pyplot as plt

# %%
adX1 = sc.read_h5ad(
    "../../../data/cscb/2022/Su_2022/adRaw_QC_012120.h5ad"
)
adX1
# Out:
# AnnData object with n_obs × n_vars = 7255 × 31065
#     obs: 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_50_genes', 'pct_counts_in_top_100_genes', 'pct_counts_in_top_200_genes', 'pct_counts_in_top_500_genes', 'percent_mito'
#     var: 'Accession', 'Chromosome', 'End', 'Start', 'Strand', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts'
#     layers: 'ambiguous', 'matrix', 'spliced', 'unspliced'

# %%
adX1.var_names
# Out:
# Index(['Xkr4', 'Gm37381', 'Rp1', 'Sox17', 'Gm37323', 'Mrpl15', 'Rgs20',
#        'Npbwr1', '4732440D04Rik', 'Gm26901',
#        ...
#        'reporter_eGFP', 'reporter_mCherry', 'selection_ampicillin',
#        'selection_blasticidin-R_pLX304', 'selection_chlormaphenicol',
#        'selection_hygromycinB', 'selection_kanamycin', 'selection_neomycin',
#        'selection_puromycin', 'selection_zeocin'],
#       dtype='object', length=31065)

# %%
adX1.obs
# Out:
#                   n_genes_by_counts  log1p_n_genes_by_counts  total_counts  \
# AAAGAACCAGTAGTTC               5210                 8.558527       25133.0
# AAACGCTTCTCCCAAC               7130                 8.872207       50300.0
# AACAGGGGTACCCGCA               4647                 8.444192       21984.0
# AAACGCTAGGAGAGGC               4723                 8.460411       22796.0
# AACACACTCGCTTGCT               3661                 8.205765       13217.0
# ...                             ...                      ...           ...
# TTTCCTCGTCTTGGTA               3629                 8.196988       15046.0
# TTTGGTTGTTCTTGTT               4770                 8.470311       24895.0
# TTTCGATTCCGATCGG               5657                 8.640826       43760.0
# TTTCCTCGTTTACCTT                297                 5.697093         442.0
# TTTGGAGTCATGGATC               6871                 8.835210       53622.0
#
#                   log1p_total_counts  pct_counts_in_top_50_genes  \
# AAAGAACCAGTAGTTC           10.131977                   21.764214
# AAACGCTTCTCCCAAC           10.825780                   24.942346
# AACAGGGGTACCCGCA            9.998116                   24.545124
# AAACGCTAGGAGAGGC           10.034384                   22.148623
# AACACACTCGCTTGCT            9.489335                   27.177120
# ...                              ...                         ...
# TTTCCTCGTCTTGGTA            9.618934                   29.768709
# TTTGGTTGTTCTTGTT           10.122462                   21.807592
# TTTCGATTCCGATCGG           10.686499                   30.648995
# TTTCCTCGTTTACCTT            6.093570                   43.665158
# TTTGGAGTCATGGATC           10.889733                   22.520607
#
#                   pct_counts_in_top_100_genes  pct_counts_in_top_200_genes  \
# AAAGAACCAGTAGTTC                    31.480524                    41.165002
# AAACGCTTCTCCCAAC                    33.980119                    43.276342
# AACAGGGGTACCCGCA                    35.530386                    45.469432
# AAACGCTAGGAGAGGC                    31.808212                    42.134585
# AACACACTCGCTTGCT                    37.905727                    47.461602
# ...                                       ...                          ...
# TTTCCTCGTCTTGGTA                    42.403297                    52.113519
# TTTGGTTGTTCTTGTT                    32.315726                    43.028721
# TTTCGATTCCGATCGG                    42.746801                    52.408592
# TTTCCTCGTTTACCTT                    55.429864                    78.054299
# TTTGGAGTCATGGATC                    32.863377                    42.956249
#
#                   pct_counts_in_top_500_genes  percent_mito
# AAAGAACCAGTAGTTC                    55.918514      0.014722
# AAACGCTTCTCCCAAC                    55.562624      0.006541
# AACAGGGGTACCCGCA                    59.834425      0.015830
# AAACGCTAGGAGAGGC                    57.865415      0.009344
# AACACACTCGCTTGCT                    61.594916      0.010214
# ...                                       ...           ...
# TTTCCTCGTCTTGGTA                    65.372857      0.012495
# TTTGGTTGTTCTTGTT                    58.859209      0.007351
# TTTCGATTCCGATCGG                    65.027422      0.016271
# TTTCCTCGTTTACCTT                   100.000000      0.167421
# TTTGGAGTCATGGATC                    57.304838      0.011040
#
# [7255 rows x 9 columns]

# %% [markdown]
# Get the sample annotation information. See Evernote: "try to rescue negatives from R1 -- Take II"
